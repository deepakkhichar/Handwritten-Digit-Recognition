# %%
import torch
import torchvision
from torchvision import transforms, datasets

# %%
 input_size = 28*28 
 hidden_layer_1_size = 500
 hidden_layer_2_size = 500 
 output_size = 10
 epochs = 250
 batch_size = 64
 learning_rate = 0.01

# %%
#Extracting MNIST data and Normalising it
transform = transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.5,), (0.5,))])

training = datasets.MNIST("", train=True, download = True,transform= transform)
testing =  datasets.MNIST("", train=False, download = True,transform= transform)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
#training_set, validation_set and testing_set
train, val = torch.utils.data.random_split(training, [50000, 10000])
print("Number of images in Training set: ",len(train))
print("Number of images in Validation set: ",len(val))
print("Number of images in Testing set: ",len(testing))
# Out:
# Number of images in Training set:  50000
# Number of images in Validation set:  10000
# Number of images in Testing set:  10000

# %%
train_set = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True)
validation_set = torch.utils.data.DataLoader(val, batch_size=batch_size, shuffle=False)
test_set = torch.utils.data.DataLoader(testing, batch_size=batch_size, shuffle=False)

# %%
#Neural Network
import torch.nn as nn
model = nn.Sequential(nn.Linear(input_size, hidden_layer_1_size), 
                      nn.ReLU(),
                      nn.Linear(hidden_layer_1_size, hidden_layer_2_size),
                      nn.ReLU(),
                      nn.Linear(hidden_layer_2_size, output_size),
                      nn.LogSoftmax(dim=1))

# %%
import torch.optim as optim
optimizer = optim.SGD(model.parameters(), lr=learning_rate) 

criterion=nn.CrossEntropyLoss()

# %%
import numpy as np
trainingloss=np.zeros(epochs)
trainingaccuracy=np.zeros(epochs)
validationloss=np.zeros(epochs)
validationaccuracy=np.zeros(epochs)

x_axis=np.zeros(epochs)

for epoch in range(epochs):
  ####################
  ### Train Loop #####
  ####################
  
  model.train()
  train_loss=0
  for data in train_set:
    X,Y=data
    X=X.view(-1,28*28)
    optimizer.zero_grad()
    outputs=model(X)
    loss=criterion(outputs,Y)
    loss.backward()
    optimizer.step()
    train_loss += loss.item()
  trainingloss[epoch]=train_loss/len(train_set)

  #########################
  ### Validation Loop #####
  #########################
  model.eval()
  valid_loss = 0
  for data in validation_set:
    X,Y=data
    X=X.view(-1,28*28)
    outputs=model(X)
    loss = criterion(outputs,Y)
    valid_loss += loss.item()
  validationloss[epoch]=valid_loss/len(validation_set)

  #validation accuracy
  correct = 0
  total = 0
  for data in validation_set:
    X, Y = data
    X=X.view(-1,28*28)
    output = model(X)
    _,predicted=torch.max(output.data, 1)
    total += Y.size(0)
    correct += (predicted == Y).sum()
  vaccuracy = 100 * correct / total
  validationaccuracy[epoch]=vaccuracy.item()

  # Training Accuracy
  correct = 0
  total = 0
  for data in train_set:
    X, Y = data
    X=X.view(-1,28*28)
    output = model(X)
    _,predicted=torch.max(output.data, 1)
    total += Y.size(0)
    correct += (predicted == Y).sum()
  taccuracy = 100 * correct / total
  trainingaccuracy[epoch]=taccuracy.item()

  x_axis[epoch]=epoch+1

  print("Epoch:",epoch+1,"  Trainloss: ",trainingloss[epoch],"  TrainAccuracy: ",trainingaccuracy[epoch],"  ValidationLoss: ",validationloss[epoch],"  ValidationAccuracy: ",validationaccuracy[epoch])
# Out:
# Epoch: 1   Trainloss:  0.981110408768782   TrainAccuracy:  88.0739974975586   ValidationLoss:  0.4477008216699977   ValidationAccuracy:  87.33999633789062
# Epoch: 2   Trainloss:  0.3769173509610431   TrainAccuracy:  89.23799896240234   ValidationLoss:  0.3903792832687402   ValidationAccuracy:  88.6500015258789
# Epoch: 3   Trainloss:  0.3195068353448835   TrainAccuracy:  89.36399841308594   ValidationLoss:  0.3668237191856287   ValidationAccuracy:  89.05999755859375
# Epoch: 4   Trainloss:  0.2876473022696307   TrainAccuracy:  91.59200286865234   ValidationLoss:  0.30909518778893597   ValidationAccuracy:  90.66999816894531
# Epoch: 5   Trainloss:  0.26330928406332765   TrainAccuracy:  92.43800354003906   ValidationLoss:  0.27710604240560227   ValidationAccuracy:  91.80000305175781
# Epoch: 6   Trainloss:  0.24098167615130428   TrainAccuracy:  93.41999816894531   ValidationLoss:  0.2562188216645247   ValidationAccuracy:  92.47000122070312
# Epoch: 7   Trainloss:  0.222215205750159   TrainAccuracy:  93.052001953125   ValidationLoss:  0.2649251823402514   ValidationAccuracy:  92.19999694824219
# Epoch: 8   Trainloss:  0.20383899028667862   TrainAccuracy:  94.4260025024414   ValidationLoss:  0.21823731933239918   ValidationAccuracy:  93.4800033569336
# Epoch: 9   Trainloss:  0.18830515220856575   TrainAccuracy:  94.74800109863281   ValidationLoss:  0.21160988395760774   ValidationAccuracy:  93.77999877929688
# Epoch: 10   Trainloss:  0.1747949888115115   TrainAccuracy:  95.41999816894531   ValidationLoss:  0.19020879247291073   ValidationAccuracy:  94.31999969482422
# Epoch: 11   Trainloss:  0.16200809232900135   TrainAccuracy:  95.65799713134766   ValidationLoss:  0.18040116567900227   ValidationAccuracy:  94.62000274658203
# Epoch: 12   Trainloss:  0.15113955228577566   TrainAccuracy:  94.96399688720703   ValidationLoss:  0.195941564478692   ValidationAccuracy:  94.19000244140625
# Epoch: 13   Trainloss:  0.14140472217889316   TrainAccuracy:  96.08999633789062   ValidationLoss:  0.16663394334494688   ValidationAccuracy:  94.93000030517578
# Epoch: 14   Trainloss:  0.13244689423162156   TrainAccuracy:  96.35600280761719   ValidationLoss:  0.16164495924096198   ValidationAccuracy:  95.13999938964844
# Epoch: 15   Trainloss:  0.12353933100943523   TrainAccuracy:  96.60600280761719   ValidationLoss:  0.1496512528247894   ValidationAccuracy:  95.30000305175781
# Epoch: 16   Trainloss:  0.11678555254798259   TrainAccuracy:  96.87999725341797   ValidationLoss:  0.14412201110534606   ValidationAccuracy:  95.58000183105469
# Epoch: 17   Trainloss:  0.11004198129381747   TrainAccuracy:  96.76399993896484   ValidationLoss:  0.1487709320607079   ValidationAccuracy:  95.29000091552734
# Epoch: 18   Trainloss:  0.10386032306248574   TrainAccuracy:  97.29199981689453   ValidationLoss:  0.13267037659219116   ValidationAccuracy:  95.94999694824219
# Epoch: 19   Trainloss:  0.09807154220288329   TrainAccuracy:  97.39800262451172   ValidationLoss:  0.12879661433873282   ValidationAccuracy:  95.98999786376953
# Epoch: 20   Trainloss:  0.09284449632867904   TrainAccuracy:  95.75   ValidationLoss:  0.17175080287893107   ValidationAccuracy:  94.58999633789062
# Epoch: 21   Trainloss:  0.08833621558792831   TrainAccuracy:  97.06600189208984   ValidationLoss:  0.13779326619663437   ValidationAccuracy:  95.41999816894531
# Epoch: 22   Trainloss:  0.08386549982778213   TrainAccuracy:  97.48799896240234   ValidationLoss:  0.12815280813889898   ValidationAccuracy:  95.9800033569336
# Epoch: 23   Trainloss:  0.07940035415491771   TrainAccuracy:  97.91400146484375   ValidationLoss:  0.11634365050418741   ValidationAccuracy:  96.4800033569336
# Epoch: 24   Trainloss:  0.07561130316980431   TrainAccuracy:  97.96399688720703   ValidationLoss:  0.11729303622843733   ValidationAccuracy:  96.4000015258789
# Epoch: 25   Trainloss:  0.07203316898442462   TrainAccuracy:  98.08599853515625   ValidationLoss:  0.10978266873818104   ValidationAccuracy:  96.62000274658203
# Epoch: 26   Trainloss:  0.06819274511231142   TrainAccuracy:  98.24400329589844   ValidationLoss:  0.10929649326784216   ValidationAccuracy:  96.68000030517578
# Epoch: 27   Trainloss:  0.06524852283842042   TrainAccuracy:  98.3219985961914   ValidationLoss:  0.10674577264506725   ValidationAccuracy:  96.77999877929688
# Epoch: 28   Trainloss:  0.06216063531999336   TrainAccuracy:  98.37000274658203   ValidationLoss:  0.10959205613323268   ValidationAccuracy:  96.58999633789062
# Epoch: 29   Trainloss:  0.05894581036096739   TrainAccuracy:  96.12200164794922   ValidationLoss:  0.17630845959636438   ValidationAccuracy:  94.52999877929688
# Epoch: 30   Trainloss:  0.05690678893147832   TrainAccuracy:  98.59200286865234   ValidationLoss:  0.09983768025828395   ValidationAccuracy:  96.86000061035156
# Epoch: 31   Trainloss:  0.05405710913631541   TrainAccuracy:  98.68399810791016   ValidationLoss:  0.09975672795609304   ValidationAccuracy:  96.87000274658203
# Epoch: 32   Trainloss:  0.05163604669187151   TrainAccuracy:  98.69400024414062   ValidationLoss:  0.09889313427933083   ValidationAccuracy:  96.91000366210938
# Epoch: 33   Trainloss:  0.049293356143709874   TrainAccuracy:  98.75800323486328   ValidationLoss:  0.0961174407623898   ValidationAccuracy:  96.98999786376953
# Epoch: 34   Trainloss:  0.04741967857346091   TrainAccuracy:  98.83200073242188   ValidationLoss:  0.09655730614059005   ValidationAccuracy:  96.9000015258789
# Epoch: 35   Trainloss:  0.045064207813118956   TrainAccuracy:  98.86199951171875   ValidationLoss:  0.09659341229481777   ValidationAccuracy:  96.97000122070312
# Epoch: 36   Trainloss:  0.04242004164377861   TrainAccuracy:  99.00399780273438   ValidationLoss:  0.09526943351041264   ValidationAccuracy:  97.05999755859375
# Epoch: 37   Trainloss:  0.04131691303887807   TrainAccuracy:  99.01799774169922   ValidationLoss:  0.09333488508275929   ValidationAccuracy:  97.1500015258789
# Epoch: 38   Trainloss:  0.03949460449992963   TrainAccuracy:  97.11399841308594   ValidationLoss:  0.14768283600046947   ValidationAccuracy:  95.29000091552734
# Epoch: 39   Trainloss:  0.03800886656488756   TrainAccuracy:  99.11599731445312   ValidationLoss:  0.09139234788573472   ValidationAccuracy:  97.19999694824219
# Epoch: 40   Trainloss:  0.03670591271340685   TrainAccuracy:  99.26799774169922   ValidationLoss:  0.08972739535947419   ValidationAccuracy:  97.2300033569336
# Epoch: 41   Trainloss:  0.034733883125464556   TrainAccuracy:  99.1719970703125   ValidationLoss:  0.09109177570908693   ValidationAccuracy:  97.0999984741211
# Epoch: 42   Trainloss:  0.033205776290772746   TrainAccuracy:  99.33599853515625   ValidationLoss:  0.08936036196329696   ValidationAccuracy:  97.29000091552734
# Epoch: 43   Trainloss:  0.03206176792516771   TrainAccuracy:  99.23999786376953   ValidationLoss:  0.09055926187918967   ValidationAccuracy:  97.1500015258789
# Epoch: 44   Trainloss:  0.030990239159832886   TrainAccuracy:  99.41000366210938   ValidationLoss:  0.08984312778902329   ValidationAccuracy:  97.23999786376953
# Epoch: 45   Trainloss:  0.02956425104691597   TrainAccuracy:  99.20600128173828   ValidationLoss:  0.09726365947811182   ValidationAccuracy:  96.91999816894531
# Epoch: 46   Trainloss:  0.02833219040605023   TrainAccuracy:  99.37799835205078   ValidationLoss:  0.08816397635438213   ValidationAccuracy:  97.18000030517578
# Epoch: 47   Trainloss:  0.027049349696116994   TrainAccuracy:  98.58799743652344   ValidationLoss:  0.11005427151515036   ValidationAccuracy:  96.77999877929688
# Epoch: 48   Trainloss:  0.026108451409722722   TrainAccuracy:  99.50399780273438   ValidationLoss:  0.08660468697595368   ValidationAccuracy:  97.3499984741211
# Epoch: 49   Trainloss:  0.02515537712066208   TrainAccuracy:  98.18800354003906   ValidationLoss:  0.1269546148432478   ValidationAccuracy:  96.0
# Epoch: 50   Trainloss:  0.024148904300881954   TrainAccuracy:  99.4020004272461   ValidationLoss:  0.09294203708873718   ValidationAccuracy:  97.12999725341797
# Epoch: 51   Trainloss:  0.02306032589311614   TrainAccuracy:  99.55999755859375   ValidationLoss:  0.08772297245657938   ValidationAccuracy:  97.33000183105469
# Epoch: 52   Trainloss:  0.022037029144433957   TrainAccuracy:  99.64800262451172   ValidationLoss:  0.08654958208441545   ValidationAccuracy:  97.44000244140625
# Epoch: 53   Trainloss:  0.021235010129131038   TrainAccuracy:  99.68000030517578   ValidationLoss:  0.08646045599405648   ValidationAccuracy:  97.37000274658203
# Epoch: 54   Trainloss:  0.020435858057285455   TrainAccuracy:  99.41600036621094   ValidationLoss:  0.0913712106827516   ValidationAccuracy:  97.12999725341797
# Epoch: 55   Trainloss:  0.019761096109407465   TrainAccuracy:  99.61399841308594   ValidationLoss:  0.088438105398706   ValidationAccuracy:  97.2699966430664
# Epoch: 56   Trainloss:  0.01885777004905726   TrainAccuracy:  99.71399688720703   ValidationLoss:  0.08728888651703122   ValidationAccuracy:  97.33999633789062
# Epoch: 57   Trainloss:  0.018270275582794024   TrainAccuracy:  99.72000122070312   ValidationLoss:  0.0882824451030843   ValidationAccuracy:  97.31999969482422
# Epoch: 58   Trainloss:  0.017475227971383803   TrainAccuracy:  99.78800201416016   ValidationLoss:  0.08471130487022649   ValidationAccuracy:  97.43000030517578
# Epoch: 59   Trainloss:  0.0168032573241725   TrainAccuracy:  99.75399780273438   ValidationLoss:  0.08768141314841119   ValidationAccuracy:  97.33999633789062
# Epoch: 60   Trainloss:  0.01623352524667235   TrainAccuracy:  99.79399871826172   ValidationLoss:  0.08642118608513788   ValidationAccuracy:  97.41999816894531
# Epoch: 61   Trainloss:  0.015425691033935035   TrainAccuracy:  99.28600311279297   ValidationLoss:  0.10582494492135396   ValidationAccuracy:  96.80999755859375
# Epoch: 62   Trainloss:  0.014950343558345647   TrainAccuracy:  99.7979965209961   ValidationLoss:  0.08643431721809824   ValidationAccuracy:  97.4000015258789
# Epoch: 63   Trainloss:  0.01447747276692182   TrainAccuracy:  99.84600067138672   ValidationLoss:  0.08853638684859048   ValidationAccuracy:  97.36000061035156
# Epoch: 64   Trainloss:  0.013706227331279356   TrainAccuracy:  99.85800170898438   ValidationLoss:  0.08557095108509277   ValidationAccuracy:  97.37000274658203
# Epoch: 65   Trainloss:  0.01345755424766737   TrainAccuracy:  99.80999755859375   ValidationLoss:  0.08889994562149736   ValidationAccuracy:  97.37000274658203
# Epoch: 66   Trainloss:  0.012752046622216816   TrainAccuracy:  99.86599731445312   ValidationLoss:  0.08535400010529716   ValidationAccuracy:  97.45999908447266
# Epoch: 67   Trainloss:  0.012420584088089564   TrainAccuracy:  99.8759994506836   ValidationLoss:  0.08821286334638383   ValidationAccuracy:  97.44999694824219
# Epoch: 68   Trainloss:  0.011992337132442047   TrainAccuracy:  98.84600067138672   ValidationLoss:  0.11968800770252302   ValidationAccuracy:  96.58999633789062
# Epoch: 69   Trainloss:  0.011573249120679101   TrainAccuracy:  99.83799743652344   ValidationLoss:  0.086674093400057   ValidationAccuracy:  97.33999633789062
# Epoch: 70   Trainloss:  0.011079634446293458   TrainAccuracy:  99.83599853515625   ValidationLoss:  0.0912906266120485   ValidationAccuracy:  97.13999938964844
# Epoch: 71   Trainloss:  0.010693484917538926   TrainAccuracy:  99.90399932861328   ValidationLoss:  0.0863756478336272   ValidationAccuracy:  97.3499984741211
# Epoch: 72   Trainloss:  0.010357242319128497   TrainAccuracy:  99.91600036621094   ValidationLoss:  0.08622583729002897   ValidationAccuracy:  97.43000030517578
# Epoch: 73   Trainloss:  0.009983124165392905   TrainAccuracy:  99.9000015258789   ValidationLoss:  0.08981240371458683   ValidationAccuracy:  97.43000030517578
# Epoch: 74   Trainloss:  0.009616728287676702   TrainAccuracy:  99.92400360107422   ValidationLoss:  0.08636558395113417   ValidationAccuracy:  97.41999816894531
# Epoch: 75   Trainloss:  0.00938888751853155   TrainAccuracy:  99.89800262451172   ValidationLoss:  0.09083722753095838   ValidationAccuracy:  97.47000122070312
# Epoch: 76   Trainloss:  0.009100501041520265   TrainAccuracy:  99.91999816894531   ValidationLoss:  0.08742464055061773   ValidationAccuracy:  97.4800033569336
# Epoch: 77   Trainloss:  0.008724042698871963   TrainAccuracy:  99.93000030517578   ValidationLoss:  0.08751591046712996   ValidationAccuracy:  97.41999816894531
# Epoch: 78   Trainloss:  0.008395484609231936   TrainAccuracy:  99.48799896240234   ValidationLoss:  0.1049384075659253   ValidationAccuracy:  97.05999755859375
# Epoch: 79   Trainloss:  0.008272073917550004   TrainAccuracy:  99.91799926757812   ValidationLoss:  0.09134611853596362   ValidationAccuracy:  97.44000244140625
# Epoch: 80   Trainloss:  0.007972717994292293   TrainAccuracy:  99.94400024414062   ValidationLoss:  0.08932359345723685   ValidationAccuracy:  97.43000030517578
# Epoch: 81   Trainloss:  0.007824038361746144   TrainAccuracy:  99.9000015258789   ValidationLoss:  0.09381897049376912   ValidationAccuracy:  97.36000061035156
# Epoch: 82   Trainloss:  0.007368247921425549   TrainAccuracy:  99.9540023803711   ValidationLoss:  0.08949614031165082   ValidationAccuracy:  97.37000274658203
# Epoch: 83   Trainloss:  0.007303552621903488   TrainAccuracy:  99.95800018310547   ValidationLoss:  0.08886518550255917   ValidationAccuracy:  97.44000244140625
# Epoch: 84   Trainloss:  0.007067922881105915   TrainAccuracy:  99.9520034790039   ValidationLoss:  0.08966138884688396   ValidationAccuracy:  97.44000244140625
# Epoch: 85   Trainloss:  0.006803804754430358   TrainAccuracy:  99.96800231933594   ValidationLoss:  0.0879036474757558   ValidationAccuracy:  97.44999694824219
# Epoch: 86   Trainloss:  0.006570627643166127   TrainAccuracy:  99.96800231933594   ValidationLoss:  0.08899833913317846   ValidationAccuracy:  97.44000244140625
# Epoch: 87   Trainloss:  0.006408126740467787   TrainAccuracy:  99.97000122070312   ValidationLoss:  0.08949387217200788   ValidationAccuracy:  97.41000366210938
# Epoch: 88   Trainloss:  0.006200671261746634   TrainAccuracy:  99.95999908447266   ValidationLoss:  0.08926665329390686   ValidationAccuracy:  97.45999908447266
# Epoch: 89   Trainloss:  0.006013766501743175   TrainAccuracy:  99.96399688720703   ValidationLoss:  0.09012841592829417   ValidationAccuracy:  97.37000274658203
# Epoch: 90   Trainloss:  0.005891559927342007   TrainAccuracy:  99.96800231933594   ValidationLoss:  0.0895270964573434   ValidationAccuracy:  97.4800033569336
# Epoch: 91   Trainloss:  0.0057755865858957235   TrainAccuracy:  99.9739990234375   ValidationLoss:  0.08964864812271557   ValidationAccuracy:  97.43000030517578
# Epoch: 92   Trainloss:  0.005564051736204271   TrainAccuracy:  99.97200012207031   ValidationLoss:  0.09086670414107158   ValidationAccuracy:  97.52999877929688
# Epoch: 93   Trainloss:  0.005377988726945485   TrainAccuracy:  99.97799682617188   ValidationLoss:  0.08963785414171707   ValidationAccuracy:  97.47000122070312
# Epoch: 94   Trainloss:  0.005239019362183581   TrainAccuracy:  99.97000122070312   ValidationLoss:  0.09184933057949125   ValidationAccuracy:  97.41999816894531
# Epoch: 95   Trainloss:  0.005098845432390389   TrainAccuracy:  99.96600341796875   ValidationLoss:  0.09110823240050317   ValidationAccuracy:  97.41000366210938
# Epoch: 96   Trainloss:  0.004988874275529998   TrainAccuracy:  99.9739990234375   ValidationLoss:  0.0906966657595224   ValidationAccuracy:  97.37999725341797
# Epoch: 97   Trainloss:  0.0048455077803248895   TrainAccuracy:  99.95999908447266   ValidationLoss:  0.09329091160666422   ValidationAccuracy:  97.4000015258789
# Epoch: 98   Trainloss:  0.004731299582092613   TrainAccuracy:  99.97799682617188   ValidationLoss:  0.09107936532247758   ValidationAccuracy:  97.48999786376953
# Epoch: 99   Trainloss:  0.004583909448998881   TrainAccuracy:  99.9800033569336   ValidationLoss:  0.09018941257832272   ValidationAccuracy:  97.43000030517578
# Epoch: 100   Trainloss:  0.004537031091081248   TrainAccuracy:  99.97799682617188   ValidationLoss:  0.09182630344104929   ValidationAccuracy:  97.48999786376953
# Epoch: 101   Trainloss:  0.004367761773519445   TrainAccuracy:  99.98200225830078   ValidationLoss:  0.09099192835235224   ValidationAccuracy:  97.51000213623047
# Epoch: 102   Trainloss:  0.004240789474077437   TrainAccuracy:  99.9800033569336   ValidationLoss:  0.09308142891019482   ValidationAccuracy:  97.47000122070312
# Epoch: 103   Trainloss:  0.004153653360454275   TrainAccuracy:  99.97599792480469   ValidationLoss:  0.09163832698098182   ValidationAccuracy:  97.52999877929688
# Epoch: 104   Trainloss:  0.004110704327490159   TrainAccuracy:  99.98600006103516   ValidationLoss:  0.09157065444612567   ValidationAccuracy:  97.52999877929688
# Epoch: 105   Trainloss:  0.003958942409528269   TrainAccuracy:  99.98999786376953   ValidationLoss:  0.09240626195988064   ValidationAccuracy:  97.48999786376953
# Epoch: 106   Trainloss:  0.0038982643149155245   TrainAccuracy:  99.99400329589844   ValidationLoss:  0.09197861123372204   ValidationAccuracy:  97.48999786376953
# Epoch: 107   Trainloss:  0.0037788393732849294   TrainAccuracy:  99.99199676513672   ValidationLoss:  0.09206770977443218   ValidationAccuracy:  97.4800033569336
# Epoch: 108   Trainloss:  0.0036965479822772796   TrainAccuracy:  99.98400115966797   ValidationLoss:  0.09291059161274276   ValidationAccuracy:  97.4800033569336
# Epoch: 109   Trainloss:  0.0036653901836910772   TrainAccuracy:  99.99400329589844   ValidationLoss:  0.09209059314375186   ValidationAccuracy:  97.44999694824219
# Epoch: 110   Trainloss:  0.0035426870527978846   TrainAccuracy:  99.98799896240234   ValidationLoss:  0.09264131706815278   ValidationAccuracy:  97.51000213623047
# Epoch: 111   Trainloss:  0.0033919609200274586   TrainAccuracy:  99.98400115966797   ValidationLoss:  0.09403230106693679   ValidationAccuracy:  97.38999938964844
# Epoch: 112   Trainloss:  0.003377459699931421   TrainAccuracy:  99.99400329589844   ValidationLoss:  0.09214023023711779   ValidationAccuracy:  97.44999694824219
# Epoch: 113   Trainloss:  0.003305864913756495   TrainAccuracy:  99.98799896240234   ValidationLoss:  0.09466993285799628   ValidationAccuracy:  97.5
# Epoch: 114   Trainloss:  0.003225243259317336   TrainAccuracy:  99.98999786376953   ValidationLoss:  0.09288265247823511   ValidationAccuracy:  97.47000122070312
# Epoch: 115   Trainloss:  0.003154330051486509   TrainAccuracy:  99.99199676513672   ValidationLoss:  0.09254181643786312   ValidationAccuracy:  97.47000122070312
# Epoch: 116   Trainloss:  0.0030964347409576302   TrainAccuracy:  99.99400329589844   ValidationLoss:  0.0937148801061832   ValidationAccuracy:  97.41000366210938
# Epoch: 117   Trainloss:  0.003028407633333849   TrainAccuracy:  99.98799896240234   ValidationLoss:  0.09380764501296492   ValidationAccuracy:  97.48999786376953
# Epoch: 118   Trainloss:  0.0029804706568648093   TrainAccuracy:  99.99800109863281   ValidationLoss:  0.09318116433614647   ValidationAccuracy:  97.5
# Epoch: 119   Trainloss:  0.0029028604856467166   TrainAccuracy:  99.99800109863281   ValidationLoss:  0.09372659132109248   ValidationAccuracy:  97.5
# Epoch: 120   Trainloss:  0.002841337088877639   TrainAccuracy:  99.99800109863281   ValidationLoss:  0.09407734234639738   ValidationAccuracy:  97.44999694824219
# Epoch: 121   Trainloss:  0.0028072085286512355   TrainAccuracy:  99.99800109863281   ValidationLoss:  0.09391508545817556   ValidationAccuracy:  97.45999908447266
# Epoch: 122   Trainloss:  0.0027319359847412304   TrainAccuracy:  99.99600219726562   ValidationLoss:  0.09412904515406258   ValidationAccuracy:  97.4800033569336
# Epoch: 123   Trainloss:  0.0026717394324051705   TrainAccuracy:  99.99600219726562   ValidationLoss:  0.09521249807511113   ValidationAccuracy:  97.4800033569336
# Epoch: 124   Trainloss:  0.002627188457044936   TrainAccuracy:  99.99400329589844   ValidationLoss:  0.09555772179802569   ValidationAccuracy:  97.5
# Epoch: 125   Trainloss:  0.002592702062971428   TrainAccuracy:  99.99800109863281   ValidationLoss:  0.09425490735458161   ValidationAccuracy:  97.45999908447266
# Epoch: 126   Trainloss:  0.002528525395848094   TrainAccuracy:  99.99600219726562   ValidationLoss:  0.09442931695596188   ValidationAccuracy:  97.47000122070312
# Epoch: 127   Trainloss:  0.0024994956839712373   TrainAccuracy:  99.99600219726562   ValidationLoss:  0.09484757445870334   ValidationAccuracy:  97.47000122070312
# Epoch: 128   Trainloss:  0.0024347685083858264   TrainAccuracy:  99.99800109863281   ValidationLoss:  0.0948683491332518   ValidationAccuracy:  97.45999908447266
# Epoch: 129   Trainloss:  0.0024162327849401146   TrainAccuracy:  99.99800109863281   ValidationLoss:  0.09539919259667301   ValidationAccuracy:  97.48999786376953
# Epoch: 130   Trainloss:  0.0023612145101614334   TrainAccuracy:  99.99800109863281   ValidationLoss:  0.09518839237554545   ValidationAccuracy:  97.51000213623047
# Epoch: 131   Trainloss:  0.002309332577190633   TrainAccuracy:  99.99800109863281   ValidationLoss:  0.09474230330962218   ValidationAccuracy:  97.47000122070312
# Epoch: 132   Trainloss:  0.0023008119647072263   TrainAccuracy:  99.99800109863281   ValidationLoss:  0.0948361300284354   ValidationAccuracy:  97.5
# Epoch: 133   Trainloss:  0.0022363699699083314   TrainAccuracy:  100.0   ValidationLoss:  0.09583398764382063   ValidationAccuracy:  97.4800033569336
# Epoch: 134   Trainloss:  0.002202853170700137   TrainAccuracy:  99.99800109863281   ValidationLoss:  0.09591174404250193   ValidationAccuracy:  97.43000030517578
# Epoch: 135   Trainloss:  0.0021736711784176017   TrainAccuracy:  99.99800109863281   ValidationLoss:  0.09545164807355935   ValidationAccuracy:  97.4800033569336
# Epoch: 136   Trainloss:  0.0021432723256100154   TrainAccuracy:  99.99800109863281   ValidationLoss:  0.09616060564331069   ValidationAccuracy:  97.48999786376953
# Epoch: 137   Trainloss:  0.0021011136409877116   TrainAccuracy:  100.0   ValidationLoss:  0.09578196916419265   ValidationAccuracy:  97.47000122070312
# Epoch: 138   Trainloss:  0.0020783158891965027   TrainAccuracy:  100.0   ValidationLoss:  0.09637790092834898   ValidationAccuracy:  97.45999908447266
# Epoch: 139   Trainloss:  0.00204621363375985   TrainAccuracy:  99.99800109863281   ValidationLoss:  0.09590157703046982   ValidationAccuracy:  97.52999877929688
# Epoch: 140   Trainloss:  0.0020060084374321392   TrainAccuracy:  100.0   ValidationLoss:  0.09630710965320527   ValidationAccuracy:  97.4800033569336
# Epoch: 141   Trainloss:  0.001969573740221267   TrainAccuracy:  100.0   ValidationLoss:  0.09643236233665205   ValidationAccuracy:  97.51000213623047
# Epoch: 142   Trainloss:  0.0019405580420434698   TrainAccuracy:  100.0   ValidationLoss:  0.09666752780451748   ValidationAccuracy:  97.43000030517578
# Epoch: 143   Trainloss:  0.001930876493347836   TrainAccuracy:  100.0   ValidationLoss:  0.09657946425227962   ValidationAccuracy:  97.51000213623047
# Epoch: 144   Trainloss:  0.0018805125504667375   TrainAccuracy:  100.0   ValidationLoss:  0.09650590174715035   ValidationAccuracy:  97.5199966430664
# Epoch: 145   Trainloss:  0.001868372263317696   TrainAccuracy:  99.99800109863281   ValidationLoss:  0.09668543732036046   ValidationAccuracy:  97.44999694824219
# Epoch: 146   Trainloss:  0.001848542250478492   TrainAccuracy:  100.0   ValidationLoss:  0.09697561224362336   ValidationAccuracy:  97.4800033569336
# Epoch: 147   Trainloss:  0.0018116554164107654   TrainAccuracy:  100.0   ValidationLoss:  0.09717500766400569   ValidationAccuracy:  97.51000213623047
# Epoch: 148   Trainloss:  0.0017848462883710248   TrainAccuracy:  100.0   ValidationLoss:  0.09762170234328776   ValidationAccuracy:  97.48999786376953
# Epoch: 149   Trainloss:  0.0017396642920768659   TrainAccuracy:  99.99800109863281   ValidationLoss:  0.0980820657286519   ValidationAccuracy:  97.44999694824219
# Epoch: 150   Trainloss:  0.0017347087703042012   TrainAccuracy:  100.0   ValidationLoss:  0.09777817820296804   ValidationAccuracy:  97.45999908447266
# Epoch: 151   Trainloss:  0.001710584158827911   TrainAccuracy:  100.0   ValidationLoss:  0.09791938343778094   ValidationAccuracy:  97.45999908447266
# Epoch: 152   Trainloss:  0.0016909027558389207   TrainAccuracy:  100.0   ValidationLoss:  0.09738698488695119   ValidationAccuracy:  97.51000213623047
# Epoch: 153   Trainloss:  0.0016764663378591202   TrainAccuracy:  100.0   ValidationLoss:  0.09803060690052923   ValidationAccuracy:  97.44000244140625
# Epoch: 154   Trainloss:  0.0016447968287848244   TrainAccuracy:  100.0   ValidationLoss:  0.09781310299434495   ValidationAccuracy:  97.47000122070312
# Epoch: 155   Trainloss:  0.001619705102893466   TrainAccuracy:  100.0   ValidationLoss:  0.0986523459661121   ValidationAccuracy:  97.47000122070312
# Epoch: 156   Trainloss:  0.0015956110889124094   TrainAccuracy:  100.0   ValidationLoss:  0.09843954171690271   ValidationAccuracy:  97.5
# Epoch: 157   Trainloss:  0.0015953543827674501   TrainAccuracy:  100.0   ValidationLoss:  0.09831585354353083   ValidationAccuracy:  97.52999877929688
# Epoch: 158   Trainloss:  0.0015561123614773647   TrainAccuracy:  100.0   ValidationLoss:  0.09857334897103223   ValidationAccuracy:  97.54000091552734
# Epoch: 159   Trainloss:  0.0015364152912023391   TrainAccuracy:  99.99800109863281   ValidationLoss:  0.09851841232364004   ValidationAccuracy:  97.48999786376953
# Epoch: 160   Trainloss:  0.0015373150045049193   TrainAccuracy:  100.0   ValidationLoss:  0.09956010162712084   ValidationAccuracy:  97.52999877929688
# Epoch: 161   Trainloss:  0.001510405512445498   TrainAccuracy:  100.0   ValidationLoss:  0.09866353248961189   ValidationAccuracy:  97.52999877929688
# Epoch: 162   Trainloss:  0.0014838241283362612   TrainAccuracy:  100.0   ValidationLoss:  0.0991144147831092   ValidationAccuracy:  97.4800033569336
# Epoch: 163   Trainloss:  0.0014663110514703775   TrainAccuracy:  100.0   ValidationLoss:  0.0988526946671213   ValidationAccuracy:  97.51000213623047
# Epoch: 164   Trainloss:  0.0014670389496027302   TrainAccuracy:  100.0   ValidationLoss:  0.09985435091158443   ValidationAccuracy:  97.5
# Epoch: 165   Trainloss:  0.0014490731691577932   TrainAccuracy:  100.0   ValidationLoss:  0.09936866353519071   ValidationAccuracy:  97.51000213623047
# Epoch: 166   Trainloss:  0.001415414940341405   TrainAccuracy:  100.0   ValidationLoss:  0.09922951959200711   ValidationAccuracy:  97.45999908447266
# Epoch: 167   Trainloss:  0.0013950515505405205   TrainAccuracy:  100.0   ValidationLoss:  0.09980966179966437   ValidationAccuracy:  97.45999908447266
# Epoch: 168   Trainloss:  0.00138573625800371   TrainAccuracy:  100.0   ValidationLoss:  0.09926816623600104   ValidationAccuracy:  97.5
# Epoch: 169   Trainloss:  0.0013686626659208418   TrainAccuracy:  100.0   ValidationLoss:  0.09952313561136794   ValidationAccuracy:  97.5
# Epoch: 170   Trainloss:  0.0013508050089322096   TrainAccuracy:  100.0   ValidationLoss:  0.09933906557598443   ValidationAccuracy:  97.48999786376953
# Epoch: 171   Trainloss:  0.0013388122734863072   TrainAccuracy:  100.0   ValidationLoss:  0.09931692769365837   ValidationAccuracy:  97.4800033569336
# Epoch: 172   Trainloss:  0.0013197353381123615   TrainAccuracy:  100.0   ValidationLoss:  0.09969888688104968   ValidationAccuracy:  97.51000213623047
# Epoch: 173   Trainloss:  0.0013090242632933671   TrainAccuracy:  100.0   ValidationLoss:  0.09957038034959496   ValidationAccuracy:  97.5199966430664
# Epoch: 174   Trainloss:  0.0012861229218955501   TrainAccuracy:  100.0   ValidationLoss:  0.09993516273697754   ValidationAccuracy:  97.5
# Epoch: 175   Trainloss:  0.0012889232576663648   TrainAccuracy:  100.0   ValidationLoss:  0.10044143134377252   ValidationAccuracy:  97.51000213623047
# Epoch: 176   Trainloss:  0.0012764283546113425   TrainAccuracy:  100.0   ValidationLoss:  0.09996562585108403   ValidationAccuracy:  97.4800033569336
# Epoch: 177   Trainloss:  0.0012468443537192583   TrainAccuracy:  100.0   ValidationLoss:  0.10043002035596077   ValidationAccuracy:  97.5
# Epoch: 178   Trainloss:  0.001235120287809275   TrainAccuracy:  100.0   ValidationLoss:  0.10014759893448942   ValidationAccuracy:  97.51000213623047
# Epoch: 179   Trainloss:  0.001223609332097261   TrainAccuracy:  100.0   ValidationLoss:  0.10077413169108312   ValidationAccuracy:  97.5
# Epoch: 180   Trainloss:  0.0012179722701560136   TrainAccuracy:  100.0   ValidationLoss:  0.10078936296436243   ValidationAccuracy:  97.51000213623047
# Epoch: 181   Trainloss:  0.001201570689054023   TrainAccuracy:  100.0   ValidationLoss:  0.10057268210406457   ValidationAccuracy:  97.51000213623047
# Epoch: 182   Trainloss:  0.0011850295639473317   TrainAccuracy:  100.0   ValidationLoss:  0.10125220901274218   ValidationAccuracy:  97.48999786376953
# Epoch: 183   Trainloss:  0.001174744305052676   TrainAccuracy:  100.0   ValidationLoss:  0.10116752669324389   ValidationAccuracy:  97.51000213623047
# Epoch: 184   Trainloss:  0.0011644812760833467   TrainAccuracy:  100.0   ValidationLoss:  0.10112945859101813   ValidationAccuracy:  97.5
# Epoch: 185   Trainloss:  0.0011490375595282652   TrainAccuracy:  100.0   ValidationLoss:  0.10079630903206276   ValidationAccuracy:  97.5199966430664
# Epoch: 186   Trainloss:  0.00113984350297946   TrainAccuracy:  100.0   ValidationLoss:  0.10179046408262991   ValidationAccuracy:  97.5
# Epoch: 187   Trainloss:  0.0011206844968180058   TrainAccuracy:  100.0   ValidationLoss:  0.10159150068262349   ValidationAccuracy:  97.51000213623047
# Epoch: 188   Trainloss:  0.0011179562302889414   TrainAccuracy:  100.0   ValidationLoss:  0.10149972994353865   ValidationAccuracy:  97.5
# Epoch: 189   Trainloss:  0.001115404577773062   TrainAccuracy:  100.0   ValidationLoss:  0.101430588827961   ValidationAccuracy:  97.5
# Epoch: 190   Trainloss:  0.001103690953271644   TrainAccuracy:  100.0   ValidationLoss:  0.10110063867030442   ValidationAccuracy:  97.4800033569336
# Epoch: 191   Trainloss:  0.0010868095152192158   TrainAccuracy:  100.0   ValidationLoss:  0.10227074679594599   ValidationAccuracy:  97.4800033569336
# Epoch: 192   Trainloss:  0.0010745636212810784   TrainAccuracy:  100.0   ValidationLoss:  0.1019535970053361   ValidationAccuracy:  97.51000213623047
# Epoch: 193   Trainloss:  0.0010619389699538127   TrainAccuracy:  100.0   ValidationLoss:  0.10219057220850228   ValidationAccuracy:  97.5
# Epoch: 194   Trainloss:  0.001056864784602375   TrainAccuracy:  100.0   ValidationLoss:  0.10191337274886647   ValidationAccuracy:  97.51000213623047
# Epoch: 195   Trainloss:  0.001041496738002992   TrainAccuracy:  100.0   ValidationLoss:  0.10168069657393178   ValidationAccuracy:  97.52999877929688
# Epoch: 196   Trainloss:  0.001033823299968457   TrainAccuracy:  100.0   ValidationLoss:  0.10210807114787371   ValidationAccuracy:  97.5
# Epoch: 197   Trainloss:  0.0010249747844665851   TrainAccuracy:  100.0   ValidationLoss:  0.10216081025991677   ValidationAccuracy:  97.5
# Epoch: 198   Trainloss:  0.0010108413583755863   TrainAccuracy:  100.0   ValidationLoss:  0.10251059536681255   ValidationAccuracy:  97.5199966430664
# Epoch: 199   Trainloss:  0.0010063985256840537   TrainAccuracy:  100.0   ValidationLoss:  0.10192759448548303   ValidationAccuracy:  97.4800033569336
# Epoch: 200   Trainloss:  0.0009963026304528756   TrainAccuracy:  100.0   ValidationLoss:  0.10240322743123499   ValidationAccuracy:  97.5
# Epoch: 201   Trainloss:  0.0009858298806024847   TrainAccuracy:  100.0   ValidationLoss:  0.10256181747610325   ValidationAccuracy:  97.5199966430664
# Epoch: 202   Trainloss:  0.0009824082416090485   TrainAccuracy:  100.0   ValidationLoss:  0.10232965127142729   ValidationAccuracy:  97.4800033569336
# Epoch: 203   Trainloss:  0.0009663746262856392   TrainAccuracy:  100.0   ValidationLoss:  0.10281257453333968   ValidationAccuracy:  97.52999877929688
# Epoch: 204   Trainloss:  0.0009639819106717919   TrainAccuracy:  100.0   ValidationLoss:  0.10297679013073882   ValidationAccuracy:  97.58999633789062
# Epoch: 205   Trainloss:  0.0009543946664397041   TrainAccuracy:  100.0   ValidationLoss:  0.10293214488983085   ValidationAccuracy:  97.55000305175781
# Epoch: 206   Trainloss:  0.0009385092670110861   TrainAccuracy:  100.0   ValidationLoss:  0.10300302638414946   ValidationAccuracy:  97.51000213623047
# Epoch: 207   Trainloss:  0.0009451574964692284   TrainAccuracy:  100.0   ValidationLoss:  0.1025206804054152   ValidationAccuracy:  97.4800033569336
# Epoch: 208   Trainloss:  0.0009275188151331794   TrainAccuracy:  100.0   ValidationLoss:  0.10330478122129425   ValidationAccuracy:  97.5199966430664
# Epoch: 209   Trainloss:  0.0009219582979780231   TrainAccuracy:  100.0   ValidationLoss:  0.10318873245521401   ValidationAccuracy:  97.51000213623047
# Epoch: 210   Trainloss:  0.0009119789375264979   TrainAccuracy:  100.0   ValidationLoss:  0.10319176168204823   ValidationAccuracy:  97.5
# Epoch: 211   Trainloss:  0.0009011795506044842   TrainAccuracy:  100.0   ValidationLoss:  0.10308175181196663   ValidationAccuracy:  97.52999877929688
# Epoch: 212   Trainloss:  0.0008990771000897956   TrainAccuracy:  100.0   ValidationLoss:  0.10368444932004665   ValidationAccuracy:  97.5
# Epoch: 213   Trainloss:  0.0008903430381459613   TrainAccuracy:  100.0   ValidationLoss:  0.10384473617847732   ValidationAccuracy:  97.52999877929688
# Epoch: 214   Trainloss:  0.0008868081745172195   TrainAccuracy:  100.0   ValidationLoss:  0.10357756861247103   ValidationAccuracy:  97.51000213623047
# Epoch: 215   Trainloss:  0.0008766527450235951   TrainAccuracy:  100.0   ValidationLoss:  0.10368597151183126   ValidationAccuracy:  97.48999786376953
# Epoch: 216   Trainloss:  0.0008686574988795565   TrainAccuracy:  100.0   ValidationLoss:  0.10369897823275212   ValidationAccuracy:  97.51000213623047
# Epoch: 217   Trainloss:  0.0008592953968951067   TrainAccuracy:  100.0   ValidationLoss:  0.10389530305964266   ValidationAccuracy:  97.48999786376953
# Epoch: 218   Trainloss:  0.0008565864489523068   TrainAccuracy:  100.0   ValidationLoss:  0.1039745848846193   ValidationAccuracy:  97.52999877929688
# Epoch: 219   Trainloss:  0.0008499667516618426   TrainAccuracy:  100.0   ValidationLoss:  0.10381821238989242   ValidationAccuracy:  97.48999786376953
# Epoch: 220   Trainloss:  0.0008393964564716985   TrainAccuracy:  100.0   ValidationLoss:  0.10399425508574055   ValidationAccuracy:  97.48999786376953
# Epoch: 221   Trainloss:  0.000835389849948338   TrainAccuracy:  100.0   ValidationLoss:  0.10452186363828175   ValidationAccuracy:  97.4800033569336
# Epoch: 222   Trainloss:  0.0008251620270071781   TrainAccuracy:  100.0   ValidationLoss:  0.1043642110352886   ValidationAccuracy:  97.54000091552734
# Epoch: 223   Trainloss:  0.0008199135142587782   TrainAccuracy:  100.0   ValidationLoss:  0.10417279131132809   ValidationAccuracy:  97.55000305175781
# Epoch: 224   Trainloss:  0.0008170209846755131   TrainAccuracy:  100.0   ValidationLoss:  0.1043871830877567   ValidationAccuracy:  97.52999877929688
# Epoch: 225   Trainloss:  0.000806502640736881   TrainAccuracy:  100.0   ValidationLoss:  0.10417626305711941   ValidationAccuracy:  97.55999755859375
# Epoch: 226   Trainloss:  0.0008033110809493009   TrainAccuracy:  100.0   ValidationLoss:  0.1043555072998744   ValidationAccuracy:  97.54000091552734
# Epoch: 227   Trainloss:  0.000797193972241594   TrainAccuracy:  100.0   ValidationLoss:  0.1045101751568819   ValidationAccuracy:  97.52999877929688
# Epoch: 228   Trainloss:  0.0007928007600681699   TrainAccuracy:  100.0   ValidationLoss:  0.10446768674016202   ValidationAccuracy:  97.4800033569336
# Epoch: 229   Trainloss:  0.0007834415561874243   TrainAccuracy:  100.0   ValidationLoss:  0.10482630188094254   ValidationAccuracy:  97.52999877929688
# Epoch: 230   Trainloss:  0.0007776860745515481   TrainAccuracy:  100.0   ValidationLoss:  0.10496902375867231   ValidationAccuracy:  97.51000213623047
# Epoch: 231   Trainloss:  0.0007759947480186765   TrainAccuracy:  100.0   ValidationLoss:  0.10490829692573742   ValidationAccuracy:  97.5
# Epoch: 232   Trainloss:  0.0007709698213259582   TrainAccuracy:  100.0   ValidationLoss:  0.10476434912536182   ValidationAccuracy:  97.5
# Epoch: 233   Trainloss:  0.0007647680169351183   TrainAccuracy:  100.0   ValidationLoss:  0.10521131222758065   ValidationAccuracy:  97.51000213623047
# Epoch: 234   Trainloss:  0.0007592931712034951   TrainAccuracy:  100.0   ValidationLoss:  0.1049788193446078   ValidationAccuracy:  97.52999877929688
# Epoch: 235   Trainloss:  0.0007496609189652736   TrainAccuracy:  100.0   ValidationLoss:  0.10471866772560673   ValidationAccuracy:  97.58000183105469
# Epoch: 236   Trainloss:  0.000747463956617595   TrainAccuracy:  100.0   ValidationLoss:  0.10506856378612905   ValidationAccuracy:  97.5199966430664
# Epoch: 237   Trainloss:  0.0007407417875656905   TrainAccuracy:  100.0   ValidationLoss:  0.10525580927564206   ValidationAccuracy:  97.52999877929688
# Epoch: 238   Trainloss:  0.0007367678390414244   TrainAccuracy:  100.0   ValidationLoss:  0.10553893725593796   ValidationAccuracy:  97.48999786376953
# Epoch: 239   Trainloss:  0.0007264572322154102   TrainAccuracy:  100.0   ValidationLoss:  0.10556141008028772   ValidationAccuracy:  97.52999877929688
# Epoch: 240   Trainloss:  0.0007233420040758151   TrainAccuracy:  100.0   ValidationLoss:  0.10558908057039375   ValidationAccuracy:  97.56999969482422
# Epoch: 241   Trainloss:  0.0007186007867700107   TrainAccuracy:  100.0   ValidationLoss:  0.10576221984962439   ValidationAccuracy:  97.48999786376953
# Epoch: 242   Trainloss:  0.0007111928785805439   TrainAccuracy:  100.0   ValidationLoss:  0.10533135115303108   ValidationAccuracy:  97.52999877929688
# Epoch: 243   Trainloss:  0.0007086778680826209   TrainAccuracy:  100.0   ValidationLoss:  0.10569991578191479   ValidationAccuracy:  97.52999877929688
# Epoch: 244   Trainloss:  0.0007029574417197705   TrainAccuracy:  100.0   ValidationLoss:  0.10588627585403994   ValidationAccuracy:  97.55000305175781
# Epoch: 245   Trainloss:  0.000697743254334192   TrainAccuracy:  100.0   ValidationLoss:  0.1056485448336887   ValidationAccuracy:  97.48999786376953
# Epoch: 246   Trainloss:  0.0006929920583711918   TrainAccuracy:  100.0   ValidationLoss:  0.10601877199890154   ValidationAccuracy:  97.51000213623047
# Epoch: 247   Trainloss:  0.0006907125114598889   TrainAccuracy:  100.0   ValidationLoss:  0.10614190447837929   ValidationAccuracy:  97.5
# Epoch: 248   Trainloss:  0.0006871751712945197   TrainAccuracy:  100.0   ValidationLoss:  0.10584678554152363   ValidationAccuracy:  97.52999877929688
# Epoch: 249   Trainloss:  0.0006814980676918052   TrainAccuracy:  100.0   ValidationLoss:  0.1060292201769397   ValidationAccuracy:  97.55000305175781
# Epoch: 250   Trainloss:  0.000676355194779026   TrainAccuracy:  100.0   ValidationLoss:  0.10588463208854024   ValidationAccuracy:  97.54000091552734

# %%
# Ploting the error and classification accuracy on both training and validation data over the epochs
import matplotlib.pyplot as plt
plt.figure()
plt.title(" Training Error  Vs Number of Epochs")
plt.ylabel("Training Error")
plt.xlabel("Number of Epochs")
plt.plot(x_axis,trainingloss)

plt.figure()
plt.title(" Training Accuracy  Vs Number of Epochs")
plt.ylabel("Training Accuracy")
plt.xlabel("Number of Epochs")
plt.plot(x_axis,trainingaccuracy)

plt.figure()
plt.title(" Validation Error  Vs Number of Epochs")
plt.ylabel("Validation Error")
plt.xlabel("Number of Epochs")
plt.plot(x_axis,validationloss)

plt.figure()
plt.title(" Validation Accuracy  Vs Number of Epochs")
plt.ylabel("Validation Accuracy")
plt.xlabel("Number of Epochs")
plt.plot(x_axis,validationaccuracy)

# %%
# Training Accuracy
correct = 0
total = 0
with torch.no_grad():
  for data in train_set:
    X, Y = data
    X=X.view(-1,28*28)
    output = model(X)
    _,predicted=torch.max(output.data, 1)
    total += Y.size(0)
    correct += (predicted == Y).sum()
training_accuracy = 100 * correct / total


# Testing Accuracy
correct = 0
total = 0
with torch.no_grad():
  for data in test_set:
    X, Y = data
    X=X.view(-1,28*28)
    output = model(X)
    _,predicted=torch.max(output.data, 1)
    total += Y.size(0)
    correct += (predicted == Y).sum()

testing_accuracy = 100 * correct / total

print("Training Accuracy: ",training_accuracy.item())
print("Testing Accuracy: ",testing_accuracy.item())
# Out:
# Training Accuracy:  100.0
# Testing Accuracy:  98.05999755859375

# %% [markdown]
# ## L2 Regularization

# %%
weight_decay=0.01

lmodel = nn.Sequential(nn.Linear(input_size, hidden_layer_1_size), 
                      nn.ReLU(),
                      nn.Linear(hidden_layer_1_size, hidden_layer_2_size),
                      nn.ReLU(),
                      nn.Linear(hidden_layer_2_size, output_size),
                      nn.LogSoftmax(dim=1))
loptimizer = optim.SGD(lmodel.parameters(), lr=learning_rate, weight_decay=weight_decay)

ltrainingloss=np.zeros(epochs)
ltrainingaccuracy=np.zeros(epochs)
lvalidationloss=np.zeros(epochs)
lvalidationaccuracy=np.zeros(epochs)

for epoch in range(epochs):
  ####################
  ### Train Loop #####
  ####################
  
  lmodel.train()
  ltrain_loss=0
  for data in train_set:
    X,Y=data
    X=X.view(-1,28*28)
    loptimizer.zero_grad()
    loutputs=lmodel(X)
    lloss=criterion(loutputs,Y)
    lloss.backward()
    loptimizer.step()
    ltrain_loss += lloss.item()
  ltrainingloss[epoch]=ltrain_loss/len(train_set)

  #########################
  ### Validation Loop #####
  #########################
  lmodel.eval()
  lvalid_loss = 0
  for data in validation_set:
    X,Y=data
    X=X.view(-1,28*28)
    loutputs=lmodel(X)
    lloss = criterion(loutputs,Y)
    lvalid_loss += lloss.item()
  lvalidationloss[epoch]=lvalid_loss/len(validation_set)

  #validation accuracy
  lcorrect = 0
  ltotal = 0
  for data in validation_set:
    X, Y = data
    X=X.view(-1,28*28)
    loutput = lmodel(X)
    _,lpredicted=torch.max(loutput.data, 1)
    ltotal += Y.size(0)
    lcorrect += (lpredicted == Y).sum()
  laccuracy = 100 * lcorrect / ltotal
  lvalidationaccuracy[epoch]=laccuracy.item()

  # Training Accuracy
  lcorrect = 0
  ltotal = 0
  for data in train_set:
    X, Y = data
    X=X.view(-1,28*28)
    loutput = lmodel(X)
    _,lpredicted=torch.max(loutput.data, 1)
    ltotal += Y.size(0)
    lcorrect += (lpredicted == Y).sum()
  ltaccuracy = 100 * lcorrect / ltotal
  ltrainingaccuracy[epoch]=ltaccuracy.item()

  print("Epoch:",epoch+1,"  Trainloss: ",ltrainingloss[epoch],"  TrainAccuracy: ",ltrainingaccuracy[epoch],"  ValidationLoss: ",lvalidationloss[epoch],"  ValidationAccuracy: ",lvalidationaccuracy[epoch])
# Out:
# Epoch: 1   Trainloss:  0.9964362385175417   TrainAccuracy:  87.15399932861328   ValidationLoss:  0.4743628382303153   ValidationAccuracy:  86.80000305175781
# Epoch: 2   Trainloss:  0.3989386950116938   TrainAccuracy:  89.41400146484375   ValidationLoss:  0.3851339406078788   ValidationAccuracy:  88.69999694824219
# Epoch: 3   Trainloss:  0.3440938262588075   TrainAccuracy:  90.65599822998047   ValidationLoss:  0.3482363071221455   ValidationAccuracy:  89.79000091552734
# Epoch: 4   Trainloss:  0.31736104887769656   TrainAccuracy:  91.44999694824219   ValidationLoss:  0.325186562386288   ValidationAccuracy:  90.72000122070312
# Epoch: 5   Trainloss:  0.3005721847267102   TrainAccuracy:  91.37000274658203   ValidationLoss:  0.31571691801213914   ValidationAccuracy:  90.51000213623047
# Epoch: 6   Trainloss:  0.2873439950692227   TrainAccuracy:  91.42400360107422   ValidationLoss:  0.31653414277514075   ValidationAccuracy:  90.81999969482422
# Epoch: 7   Trainloss:  0.2760954712377027   TrainAccuracy:  92.447998046875   ValidationLoss:  0.2875194167065772   ValidationAccuracy:  91.55999755859375
# Epoch: 8   Trainloss:  0.264874961760724   TrainAccuracy:  92.87799835205078   ValidationLoss:  0.27518472426636204   ValidationAccuracy:  92.06999969482422
# Epoch: 9   Trainloss:  0.2562175657400085   TrainAccuracy:  92.87200164794922   ValidationLoss:  0.27305554138247373   ValidationAccuracy:  92.06999969482422
# Epoch: 10   Trainloss:  0.24717226374865797   TrainAccuracy:  93.00199890136719   ValidationLoss:  0.27054673518724504   ValidationAccuracy:  92.13999938964844
# Epoch: 11   Trainloss:  0.23838063782971838   TrainAccuracy:  92.45800018310547   ValidationLoss:  0.27605122826091805   ValidationAccuracy:  91.79000091552734
# Epoch: 12   Trainloss:  0.23084704602694572   TrainAccuracy:  93.2979965209961   ValidationLoss:  0.25758873714003594   ValidationAccuracy:  92.66000366210938
# Epoch: 13   Trainloss:  0.2245990753345325   TrainAccuracy:  93.93800354003906   ValidationLoss:  0.24318415106861455   ValidationAccuracy:  93.06999969482422
# Epoch: 14   Trainloss:  0.21829357719444253   TrainAccuracy:  94.06600189208984   ValidationLoss:  0.2399932130886491   ValidationAccuracy:  93.19000244140625
# Epoch: 15   Trainloss:  0.21298325108483318   TrainAccuracy:  94.4000015258789   ValidationLoss:  0.2267791851880444   ValidationAccuracy:  93.66999816894531
# Epoch: 16   Trainloss:  0.20816392743545573   TrainAccuracy:  94.552001953125   ValidationLoss:  0.229028963501666   ValidationAccuracy:  93.76000213623047
# Epoch: 17   Trainloss:  0.20336991586648595   TrainAccuracy:  94.69999694824219   ValidationLoss:  0.22259128535059608   ValidationAccuracy:  93.87000274658203
# Epoch: 18   Trainloss:  0.200352320804849   TrainAccuracy:  94.83000183105469   ValidationLoss:  0.21673153635043246   ValidationAccuracy:  93.98999786376953
# Epoch: 19   Trainloss:  0.19636671992538074   TrainAccuracy:  94.78399658203125   ValidationLoss:  0.2178133599412669   ValidationAccuracy:  93.79000091552734
# Epoch: 20   Trainloss:  0.19277422554562312   TrainAccuracy:  94.89800262451172   ValidationLoss:  0.22010838876294483   ValidationAccuracy:  93.87999725341797
# Epoch: 21   Trainloss:  0.189260399588348   TrainAccuracy:  93.9739990234375   ValidationLoss:  0.2266903777790677   ValidationAccuracy:  93.2699966430664
# Epoch: 22   Trainloss:  0.18659014177158514   TrainAccuracy:  95.33000183105469   ValidationLoss:  0.2015038951756848   ValidationAccuracy:  94.5
# Epoch: 23   Trainloss:  0.18390621396872547   TrainAccuracy:  95.05400085449219   ValidationLoss:  0.2103441501878629   ValidationAccuracy:  94.19999694824219
# Epoch: 24   Trainloss:  0.18134988435660787   TrainAccuracy:  95.4000015258789   ValidationLoss:  0.20072320862940163   ValidationAccuracy:  94.62999725341797
# Epoch: 25   Trainloss:  0.17945038831180624   TrainAccuracy:  95.41999816894531   ValidationLoss:  0.2013024629396238   ValidationAccuracy:  94.48999786376953
# Epoch: 26   Trainloss:  0.17788804893184196   TrainAccuracy:  95.25800323486328   ValidationLoss:  0.1994063590362573   ValidationAccuracy:  94.3499984741211
# Epoch: 27   Trainloss:  0.17600770290378873   TrainAccuracy:  95.38600158691406   ValidationLoss:  0.20222539302839596   ValidationAccuracy:  94.56999969482422
# Epoch: 28   Trainloss:  0.1732155690136392   TrainAccuracy:  95.65399932861328   ValidationLoss:  0.19222337387170002   ValidationAccuracy:  94.54000091552734
# Epoch: 29   Trainloss:  0.17245520761384225   TrainAccuracy:  95.48400115966797   ValidationLoss:  0.19947283819412728   ValidationAccuracy:  94.48999786376953
# Epoch: 30   Trainloss:  0.1704577188653028   TrainAccuracy:  95.71399688720703   ValidationLoss:  0.19413288075263332   ValidationAccuracy:  94.8499984741211
# Epoch: 31   Trainloss:  0.1690062179999507   TrainAccuracy:  95.68199920654297   ValidationLoss:  0.19015123106681617   ValidationAccuracy:  94.63999938964844
# Epoch: 32   Trainloss:  0.1675055348945548   TrainAccuracy:  95.89399719238281   ValidationLoss:  0.18586423480586642   ValidationAccuracy:  94.94000244140625
# Epoch: 33   Trainloss:  0.1659632312167255   TrainAccuracy:  95.7760009765625   ValidationLoss:  0.1950087883290212   ValidationAccuracy:  94.8499984741211
# Epoch: 34   Trainloss:  0.1648502715856142   TrainAccuracy:  95.7699966430664   ValidationLoss:  0.1895133072308674   ValidationAccuracy:  94.61000061035156
# Epoch: 35   Trainloss:  0.16398415512040906   TrainAccuracy:  95.90599822998047   ValidationLoss:  0.18267509032776402   ValidationAccuracy:  94.87999725341797
# Epoch: 36   Trainloss:  0.16279454609793623   TrainAccuracy:  96.08999633789062   ValidationLoss:  0.18297638369214003   ValidationAccuracy:  95.08000183105469
# Epoch: 37   Trainloss:  0.16175417743547035   TrainAccuracy:  96.06600189208984   ValidationLoss:  0.18027949399629217   ValidationAccuracy:  95.04000091552734
# Epoch: 38   Trainloss:  0.16058814740927932   TrainAccuracy:  96.19400024414062   ValidationLoss:  0.17742386479286631   ValidationAccuracy:  95.11000061035156
# Epoch: 39   Trainloss:  0.1597030971466047   TrainAccuracy:  95.53399658203125   ValidationLoss:  0.1923175680504483   ValidationAccuracy:  94.63999938964844
# Epoch: 40   Trainloss:  0.15881947083089054   TrainAccuracy:  96.13200378417969   ValidationLoss:  0.1801385748538242   ValidationAccuracy:  95.08000183105469
# Epoch: 41   Trainloss:  0.15838024303164627   TrainAccuracy:  96.13400268554688   ValidationLoss:  0.1808380202692785   ValidationAccuracy:  95.05000305175781
# Epoch: 42   Trainloss:  0.15724724444472576   TrainAccuracy:  95.8499984741211   ValidationLoss:  0.18660435109001816   ValidationAccuracy:  94.76000213623047
# Epoch: 43   Trainloss:  0.1565837232953371   TrainAccuracy:  96.36000061035156   ValidationLoss:  0.17720599557943406   ValidationAccuracy:  95.37000274658203
# Epoch: 44   Trainloss:  0.15583822126393124   TrainAccuracy:  96.0479965209961   ValidationLoss:  0.1833685754685645   ValidationAccuracy:  94.91999816894531
# Epoch: 45   Trainloss:  0.15514763748116048   TrainAccuracy:  95.97799682617188   ValidationLoss:  0.1823615467377529   ValidationAccuracy:  94.97000122070312
# Epoch: 46   Trainloss:  0.15494234737513773   TrainAccuracy:  96.19000244140625   ValidationLoss:  0.17740623263796423   ValidationAccuracy:  95.2300033569336
# Epoch: 47   Trainloss:  0.15381515959320624   TrainAccuracy:  96.08000183105469   ValidationLoss:  0.18480440456965927   ValidationAccuracy:  94.98999786376953
# Epoch: 48   Trainloss:  0.15321278951280867   TrainAccuracy:  96.27200317382812   ValidationLoss:  0.17610137501529827   ValidationAccuracy:  95.12999725341797
# Epoch: 49   Trainloss:  0.15275472169146515   TrainAccuracy:  96.29399871826172   ValidationLoss:  0.17348505850810153   ValidationAccuracy:  95.22000122070312
# Epoch: 50   Trainloss:  0.15217714677648167   TrainAccuracy:  96.22799682617188   ValidationLoss:  0.17816767381255033   ValidationAccuracy:  95.12000274658203
# Epoch: 51   Trainloss:  0.1516877090763253   TrainAccuracy:  96.2979965209961   ValidationLoss:  0.17369248694295336   ValidationAccuracy:  95.2699966430664
# Epoch: 52   Trainloss:  0.15120235889616523   TrainAccuracy:  96.40599822998047   ValidationLoss:  0.17036155886521007   ValidationAccuracy:  95.37999725341797
# Epoch: 53   Trainloss:  0.1509341222836691   TrainAccuracy:  96.42400360107422   ValidationLoss:  0.17025909881303264   ValidationAccuracy:  95.41999816894531
# Epoch: 54   Trainloss:  0.1501600175686276   TrainAccuracy:  96.44599914550781   ValidationLoss:  0.17354012736279495   ValidationAccuracy:  95.30999755859375
# Epoch: 55   Trainloss:  0.15009648831623137   TrainAccuracy:  96.31800079345703   ValidationLoss:  0.17346230908563942   ValidationAccuracy:  95.4000015258789
# Epoch: 56   Trainloss:  0.14924294649697173   TrainAccuracy:  96.47200012207031   ValidationLoss:  0.17117336525279245   ValidationAccuracy:  95.3499984741211
# Epoch: 57   Trainloss:  0.14886724124269565   TrainAccuracy:  96.27200317382812   ValidationLoss:  0.17398495953174153   ValidationAccuracy:  95.12000274658203
# Epoch: 58   Trainloss:  0.14894750021645786   TrainAccuracy:  96.43599700927734   ValidationLoss:  0.17011265285835145   ValidationAccuracy:  95.44999694824219
# Epoch: 59   Trainloss:  0.14810174292958606   TrainAccuracy:  96.11199951171875   ValidationLoss:  0.1782616727101575   ValidationAccuracy:  95.08999633789062
# Epoch: 60   Trainloss:  0.1477840568041405   TrainAccuracy:  96.44400024414062   ValidationLoss:  0.17057252305138643   ValidationAccuracy:  95.33000183105469
# Epoch: 61   Trainloss:  0.14782420904054056   TrainAccuracy:  96.1719970703125   ValidationLoss:  0.18024975991552802   ValidationAccuracy:  95.05999755859375
# Epoch: 62   Trainloss:  0.14757402334600458   TrainAccuracy:  96.27400207519531   ValidationLoss:  0.17813503030379108   ValidationAccuracy:  95.16000366210938
# Epoch: 63   Trainloss:  0.14677284675104843   TrainAccuracy:  96.36599731445312   ValidationLoss:  0.17521824478913264   ValidationAccuracy:  95.2699966430664
# Epoch: 64   Trainloss:  0.1465477251145236   TrainAccuracy:  96.43800354003906   ValidationLoss:  0.16777383460170903   ValidationAccuracy:  95.58000183105469
# Epoch: 65   Trainloss:  0.14667671755947115   TrainAccuracy:  96.44400024414062   ValidationLoss:  0.17072901836815912   ValidationAccuracy:  95.22000122070312
# Epoch: 66   Trainloss:  0.1463185433450791   TrainAccuracy:  96.49199676513672   ValidationLoss:  0.17057466450010894   ValidationAccuracy:  95.44999694824219
# Epoch: 67   Trainloss:  0.1455670934208595   TrainAccuracy:  96.1760025024414   ValidationLoss:  0.17318563452761643   ValidationAccuracy:  95.05000305175781
# Epoch: 68   Trainloss:  0.14564418638853924   TrainAccuracy:  96.47200012207031   ValidationLoss:  0.16989727090498444   ValidationAccuracy:  95.4000015258789
# Epoch: 69   Trainloss:  0.1455574087569933   TrainAccuracy:  96.1760025024414   ValidationLoss:  0.1782395733389885   ValidationAccuracy:  94.94999694824219
# Epoch: 70   Trainloss:  0.14540546305496674   TrainAccuracy:  95.29000091552734   ValidationLoss:  0.1988331713494222   ValidationAccuracy:  94.30000305175781
# Epoch: 71   Trainloss:  0.14510985361912365   TrainAccuracy:  96.54199981689453   ValidationLoss:  0.17016159781035345   ValidationAccuracy:  95.33000183105469
# Epoch: 72   Trainloss:  0.1444431674640502   TrainAccuracy:  96.3499984741211   ValidationLoss:  0.1771337280797351   ValidationAccuracy:  95.29000091552734
# Epoch: 73   Trainloss:  0.14419534433242456   TrainAccuracy:  96.53600311279297   ValidationLoss:  0.1719530171174912   ValidationAccuracy:  95.27999877929688
# Epoch: 74   Trainloss:  0.1442545807594076   TrainAccuracy:  96.5999984741211   ValidationLoss:  0.16358936938700402   ValidationAccuracy:  95.54000091552734
# Epoch: 75   Trainloss:  0.14407639990053367   TrainAccuracy:  96.28199768066406   ValidationLoss:  0.17621033330252217   ValidationAccuracy:  95.19999694824219
# Epoch: 76   Trainloss:  0.14381095694611445   TrainAccuracy:  96.67400360107422   ValidationLoss:  0.1640458647280362   ValidationAccuracy:  95.61000061035156
# Epoch: 77   Trainloss:  0.14373557799307587   TrainAccuracy:  96.59200286865234   ValidationLoss:  0.16397643321828478   ValidationAccuracy:  95.66000366210938
# Epoch: 78   Trainloss:  0.14368782563568533   TrainAccuracy:  96.3239974975586   ValidationLoss:  0.17416569685480396   ValidationAccuracy:  95.29000091552734
# Epoch: 79   Trainloss:  0.14341045549744383   TrainAccuracy:  96.63999938964844   ValidationLoss:  0.1641410305431694   ValidationAccuracy:  95.48999786376953
# Epoch: 80   Trainloss:  0.14333253576779914   TrainAccuracy:  96.66799926757812   ValidationLoss:  0.1628360975367628   ValidationAccuracy:  95.5999984741211
# Epoch: 81   Trainloss:  0.1430150685817613   TrainAccuracy:  96.81199645996094   ValidationLoss:  0.16188038021895537   ValidationAccuracy:  95.6500015258789
# Epoch: 82   Trainloss:  0.14278775763214396   TrainAccuracy:  96.57599639892578   ValidationLoss:  0.16713940579989914   ValidationAccuracy:  95.37999725341797
# Epoch: 83   Trainloss:  0.14295817970696006   TrainAccuracy:  95.83599853515625   ValidationLoss:  0.18802628471593189   ValidationAccuracy:  94.66000366210938
# Epoch: 84   Trainloss:  0.14237179241293227   TrainAccuracy:  96.66000366210938   ValidationLoss:  0.16361808235857897   ValidationAccuracy:  95.55999755859375
# Epoch: 85   Trainloss:  0.1424151759242158   TrainAccuracy:  96.552001953125   ValidationLoss:  0.1702491948559026   ValidationAccuracy:  95.36000061035156
# Epoch: 86   Trainloss:  0.14228000579987798   TrainAccuracy:  96.49800109863281   ValidationLoss:  0.17040801285558446   ValidationAccuracy:  95.41999816894531
# Epoch: 87   Trainloss:  0.14222550556501923   TrainAccuracy:  96.30799865722656   ValidationLoss:  0.17483001339967083   ValidationAccuracy:  95.29000091552734
# Epoch: 88   Trainloss:  0.1419360689304369   TrainAccuracy:  96.79000091552734   ValidationLoss:  0.16258917639779438   ValidationAccuracy:  95.70999908447266
# Epoch: 89   Trainloss:  0.14138206050200078   TrainAccuracy:  96.79000091552734   ValidationLoss:  0.16379437187484874   ValidationAccuracy:  95.62000274658203
# Epoch: 90   Trainloss:  0.1418731732679831   TrainAccuracy:  96.15399932861328   ValidationLoss:  0.1755483797781027   ValidationAccuracy:  95.22000122070312
# Epoch: 91   Trainloss:  0.1418800125770328   TrainAccuracy:  96.4260025024414   ValidationLoss:  0.1680909046654109   ValidationAccuracy:  95.41000366210938
# Epoch: 92   Trainloss:  0.14139935120825878   TrainAccuracy:  96.65599822998047   ValidationLoss:  0.1671154530374867   ValidationAccuracy:  95.5199966430664
# Epoch: 93   Trainloss:  0.14132419920733671   TrainAccuracy:  96.69599914550781   ValidationLoss:  0.16312294911332192   ValidationAccuracy:  95.72000122070312
# Epoch: 94   Trainloss:  0.14112611151660037   TrainAccuracy:  96.8499984741211   ValidationLoss:  0.1619210704971271   ValidationAccuracy:  95.68000030517578
# Epoch: 95   Trainloss:  0.1412286949212975   TrainAccuracy:  95.37999725341797   ValidationLoss:  0.19761173564727139   ValidationAccuracy:  94.41999816894531
# Epoch: 96   Trainloss:  0.14096013905809207   TrainAccuracy:  96.56800079345703   ValidationLoss:  0.16524637080017168   ValidationAccuracy:  95.44999694824219
# Epoch: 97   Trainloss:  0.14090021650599854   TrainAccuracy:  96.5   ValidationLoss:  0.1678633785978624   ValidationAccuracy:  95.41000366210938
# Epoch: 98   Trainloss:  0.1409382429307379   TrainAccuracy:  96.48799896240234   ValidationLoss:  0.16818503537185633   ValidationAccuracy:  95.37999725341797
# Epoch: 99   Trainloss:  0.1405953522581045   TrainAccuracy:  96.77400207519531   ValidationLoss:  0.163034506426875   ValidationAccuracy:  95.76000213623047
# Epoch: 100   Trainloss:  0.14044145967744653   TrainAccuracy:  96.0719985961914   ValidationLoss:  0.1802444932092527   ValidationAccuracy:  95.0999984741211
# Epoch: 101   Trainloss:  0.14043783918118385   TrainAccuracy:  96.86000061035156   ValidationLoss:  0.15975149500237149   ValidationAccuracy:  95.69000244140625
# Epoch: 102   Trainloss:  0.140488292817074   TrainAccuracy:  96.71399688720703   ValidationLoss:  0.16336260778698952   ValidationAccuracy:  95.55999755859375
# Epoch: 103   Trainloss:  0.1402135187440821   TrainAccuracy:  96.83599853515625   ValidationLoss:  0.16170496213587987   ValidationAccuracy:  95.66000366210938
# Epoch: 104   Trainloss:  0.13977562125934206   TrainAccuracy:  96.61000061035156   ValidationLoss:  0.16570217133897125   ValidationAccuracy:  95.4000015258789

# %%
# Ploting the error and classification accuracy on both training and validation data over the epochs
import matplotlib.pyplot as plt
plt.figure()
plt.title(" Training Error  Vs Number of Epochs")
plt.ylabel("Training Error")
plt.xlabel("Number of Epochs")
plt.plot(x_axis,ltrainingloss)

plt.figure()
plt.title(" Training Accuracy  Vs Number of Epochs")
plt.ylabel("Training Accuracy")
plt.xlabel("Number of Epochs")
plt.plot(x_axis,ltrainingaccuracy)

plt.figure()
plt.title(" Validation Error  Vs Number of Epochs")
plt.ylabel("Validation Error")
plt.xlabel("Number of Epochs")
plt.plot(x_axis,lvalidationloss)

plt.figure()
plt.title(" Validation Accuracy  Vs Number of Epochs")
plt.ylabel("Validation Accuracy")
plt.xlabel("Number of Epochs")
plt.plot(x_axis,lvalidationaccuracy)

# %%
# Training Accuracy
lcorrect = 0
ltotal = 0
with torch.no_grad():
  for data in train_set:
    X, Y = data
    X=X.view(-1,28*28)
    loutput = lmodel(X)
    _,lpredicted=torch.max(loutput.data, 1)
    ltotal += Y.size(0)
    lcorrect += (lpredicted == Y).sum()
ltraining_accuracy = 100 * lcorrect / ltotal


# Testing Accuracy
lcorrect = 0
ltotal = 0
with torch.no_grad():
  for data in test_set:
    X, Y = data
    X=X.view(-1,28*28)
    loutput = lmodel(X)
    _,lpredicted=torch.max(loutput.data, 1)
    ltotal += Y.size(0)
    lcorrect += (lpredicted == Y).sum()

ltesting_accuracy = 100 * lcorrect / ltotal

print("Training Accuracy: ",ltraining_accuracy.item())
print("Testing Accuracy: ",ltesting_accuracy.item())

# %% [markdown]
# ## Dropout

# %%
dmodel = nn.Sequential(nn.Linear(input_size, hidden_layer_1_size), 
                      nn.ReLU(),
                      nn.Dropout(p=0.5),
                      nn.Linear(hidden_layer_1_size, hidden_layer_2_size),
                      nn.ReLU(),
                      nn.Dropout(p=0.5),
                      nn.Linear(hidden_layer_2_size, output_size),
                      nn.LogSoftmax(dim=1))
doptimizer = optim.SGD(dmodel.parameters(), lr=learning_rate)

dtrainingloss=np.zeros(epochs)
dtrainingaccuracy=np.zeros(epochs)
dvalidationloss=np.zeros(epochs)
dvalidationaccuracy=np.zeros(epochs)

for epoch in range(epochs):
  ####################
  ### Train Loop #####
  ####################
  
  dmodel.train()
  dtrain_loss=0
  for data in train_set:
    X,Y=data
    X=X.view(-1,28*28)
    doptimizer.zero_grad()
    doutputs=dmodel(X)
    dloss=criterion(doutputs,Y)
    dloss.backward()
    doptimizer.step()
    dtrain_loss += dloss.item()
  dtrainingloss[epoch]=dtrain_loss/len(train_set)

  #########################
  ### Validation Loop #####
  #########################
  dmodel.eval()
  dvalid_loss = 0
  for data in validation_set:
    X,Y=data
    X=X.view(-1,28*28)
    doutputs=dmodel(X)
    dloss = criterion(doutputs,Y)
    dvalid_loss += dloss.item()
  dvalidationloss[epoch]=dvalid_loss/len(validation_set)

  #validation accuracy
  dcorrect = 0
  dtotal = 0
  for data in validation_set:
    X, Y = data
    X=X.view(-1,28*28)
    doutput = dmodel(X)
    _,dpredicted=torch.max(doutput.data, 1)
    dtotal += Y.size(0)
    dcorrect += (dpredicted == Y).sum()
  daccuracy = 100 * dcorrect / dtotal
  dvalidationaccuracy[epoch]=daccuracy.item()

  # Training Accuracy
  dcorrect = 0
  dtotal = 0
  for data in train_set:
    X, Y = data
    X=X.view(-1,28*28)
    doutput = dmodel(X)
    _,dpredicted=torch.max(doutput.data, 1)
    dtotal += Y.size(0)
    dcorrect += (dpredicted == Y).sum()
  dtaccuracy = 100 * dcorrect / dtotal
  dtrainingaccuracy[epoch]=dtaccuracy.item()

  print("Epoch:",epoch+1,"  Trainloss: ",dtrainingloss[epoch],"  TrainAccuracy: ",dtrainingaccuracy[epoch],"  ValidationLoss: ",dvalidationloss[epoch],"  ValidationAccuracy: ",dvalidationaccuracy[epoch])

# %%
# Ploting the error and classification accuracy on both training and validation data over the epochs
import matplotlib.pyplot as plt
plt.figure()
plt.title(" Training Error  Vs Number of Epochs")
plt.ylabel("Training Error")
plt.xlabel("Number of Epochs")
plt.plot(x_axis,dtrainingloss)

plt.figure()
plt.title(" Training Accuracy  Vs Number of Epochs")
plt.ylabel("Training Accuracy")
plt.xlabel("Number of Epochs")
plt.plot(x_axis,dtrainingaccuracy)

plt.figure()
plt.title(" Validation Error  Vs Number of Epochs")
plt.ylabel("Validation Error")
plt.xlabel("Number of Epochs")
plt.plot(x_axis,dvalidationloss)

plt.figure()
plt.title(" Validation Accuracy  Vs Number of Epochs")
plt.ylabel("Validation Accuracy")
plt.xlabel("Number of Epochs")
plt.plot(x_axis,dvalidationaccuracy)

# %%
# Training Accuracy
dcorrect = 0
dtotal = 0
with torch.no_grad():
  for data in train_set:
    X, Y = data
    X=X.view(-1,28*28)
    doutput = dmodel(X)
    _,dpredicted=torch.max(doutput.data, 1)
    dtotal += Y.size(0)
    dcorrect += (dpredicted == Y).sum()
dtraining_accuracy = 100 * dcorrect / dtotal


# Testing Accuracy
dcorrect = 0
dtotal = 0
with torch.no_grad():
  for data in test_set:
    X, Y = data
    X=X.view(-1,28*28)
    doutput = dmodel(X)
    _,dpredicted=torch.max(doutput.data, 1)
    dtotal += Y.size(0)
    dcorrect += (dpredicted == Y).sum()

dtesting_accuracy = 100 * dcorrect / dtotal

print("Training Accuracy: ",dtraining_accuracy.item())
print("Testing Accuracy: ",dtesting_accuracy.item())

# %% [markdown]
# ## Early Stopping

# %%
emodel = nn.Sequential(nn.Linear(input_size, hidden_layer_1_size), 
                      nn.ReLU(),
                      nn.Linear(hidden_layer_1_size, hidden_layer_2_size),
                      nn.ReLU(),
                      nn.Linear(hidden_layer_2_size, output_size),
                      nn.LogSoftmax(dim=1))
eoptimizer = optim.SGD(emodel.parameters(), lr=learning_rate)

etrainingloss=np.zeros(epochs)
etrainingaccuracy=np.zeros(epochs)
evalidationloss=np.zeros(epochs)
evalidationaccuracy=np.zeros(epochs)

best_accuracy=0
bestepoch=0
for epoch in range(epochs):
  ####################
  ### Train Loop #####
  ####################
  
  emodel.train()
  etrain_loss=0
  for data in train_set:
    X,Y=data
    X=X.view(-1,28*28)
    eoptimizer.zero_grad()
    eoutputs=emodel(X)
    eloss=criterion(eoutputs,Y)
    eloss.backward()
    eoptimizer.step()
    etrain_loss += eloss.item()
  etrainingloss[epoch]=etrain_loss/len(train_set)

  #########################
  ### Validation Loop #####
  #########################
  emodel.eval()
  evalid_loss = 0
  for data in validation_set:
    X,Y=data
    X=X.view(-1,28*28)
    eoutputs=emodel(X)
    eloss = criterion(eoutputs,Y)
    evalid_loss += eloss.item()
  evalidationloss[epoch]=evalid_loss/len(validation_set)

  #validation accuracy
  ecorrect = 0
  etotal = 0
  for data in validation_set:
    X, Y = data
    X=X.view(-1,28*28)
    eoutput = emodel(X)
    _,epredicted=torch.max(eoutput.data, 1)
    etotal += Y.size(0)
    ecorrect += (epredicted == Y).sum()
  eaccuracy = 100 * ecorrect / etotal
  evalidationaccuracy[epoch]=eaccuracy.item()

  # Training Accuracy
  ecorrect = 0
  etotal = 0
  for data in train_set:
    X, Y = data
    X=X.view(-1,28*28)
    eoutput = emodel(X)
    _,epredicted=torch.max(eoutput.data, 1)
    etotal += Y.size(0)
    ecorrect += (epredicted == Y).sum()
  etaccuracy = 100 * ecorrect / etotal
  etrainingaccuracy[epoch]=etaccuracy.item()

  if evalidationaccuracy[epoch] > best_accuracy:
    best_accuracy = evalidationloss[epoch]
    bestepoch=epoch
    torch.save(emodel, 'best_model')

  print("Epoch:",epoch+1,"  Trainloss: ",etrainingloss[epoch],"  TrainAccuracy: ",etrainingaccuracy[epoch],"  ValidationLoss: ",evalidationloss[epoch],"  ValidationAccuracy: ",evalidationaccuracy[epoch])

print("Optimal number of Epoch for early stopping: ",bestepoch+1)
emodel = torch.load('best_model')
emodel.eval()

# %%
# Ploting the error and classification accuracy on both training and validation data over the epochs
import matplotlib.pyplot as plt
plt.figure()
plt.title(" Training Error  Vs Number of Epochs")
plt.ylabel("Training Error")
plt.xlabel("Number of Epochs")
plt.plot(x_axis[:bestepoch],etrainingloss[:bestepoch])

plt.figure()
plt.title(" Training Accuracy  Vs Number of Epochs")
plt.ylabel("Training Accuracy")
plt.xlabel("Number of Epochs")
plt.plot(x_axis[:bestepoch],etrainingaccuracy[:bestepoch])

plt.figure()
plt.title(" Validation Error  Vs Number of Epochs")
plt.ylabel("Validation Error")
plt.xlabel("Number of Epochs")
plt.plot(x_axis[:bestepoch],evalidationloss[:bestepoch])

plt.figure()
plt.title(" Validation Accuracy  Vs Number of Epochs")
plt.ylabel("Validation Accuracy")
plt.xlabel("Number of Epochs")
plt.plot(x_axis[:bestepoch],evalidationaccuracy[:bestepoch])

# %%
# Training Accuracy
ecorrect = 0
etotal = 0
with torch.no_grad():
  for data in train_set:
    X, Y = data
    X=X.view(-1,28*28)
    eoutput = emodel(X)
    _,epredicted=torch.max(eoutput.data, 1)
    etotal += Y.size(0)
    ecorrect += (epredicted == Y).sum()
etraining_accuracy = 100 * ecorrect / etotal


# Testing Accuracy
ecorrect = 0
etotal = 0
with torch.no_grad():
  for data in test_set:
    X, Y = data
    X=X.view(-1,28*28)
    eoutput = emodel(X)
    _,epredicted=torch.max(eoutput.data, 1)
    etotal += Y.size(0)
    ecorrect += (epredicted == Y).sum()

etesting_accuracy = 100 * ecorrect / etotal

print("Training Accuracy: ",etraining_accuracy.item())
print("Testing Accuracy: ",etesting_accuracy.item())
